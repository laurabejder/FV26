# %%
import sys
import paramiko
import os
import re

from config import HOST, PORT, USERNAME, PASSWORD, REMOTE_PATH

# %%
transport = paramiko.Transport((HOST, PORT))
transport.connect(username=USERNAME, password=PASSWORD)
sftp = paramiko.SFTPClient.from_transport(transport)

# go into the data folder
sftp.chdir("/data/folketingsvalg-135-24-03-2026/verifikation/")

# print all the folders in the data folder
folders = sftp.listdir()
print("Folders in data folder:")
for folder in folders:
    print(folder)
# Out:
# ---------------------------------------------------------------------------
# SSHException                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 transport = paramiko.Transport((HOST, PORT))
#       2 transport.connect(username=USERNAME, password=PASSWORD)
#       3 sftp = paramiko.SFTPClient.from_transport(transport)
#
# File ~/Library/CloudStorage/OneDrive-AlrowMedia/Dokumenter/GitHub/FV26/.venv/lib/python3.13/site-packages/paramiko/transport.py:494, in Transport.__init__(self, sock, default_window_size, default_max_packet_size, gss_kex, gss_deleg_creds, disabled_algorithms, server_sig_algs, strict_kex, packetizer_class)
#     492                 break
#     493     else:
# --> 494         raise SSHException(
#     495             "Unable to connect to {}: {}".format(hostname, reason)
#     496         )
#     497 # okay, normal socket-ish flow here...
#     498 threading.Thread.__init__(self)
#
# SSHException: Unable to connect to data.valg.dk: [Errno 61] Connection refused

# %% [markdown]
# Folders in data folder:
# kandidat-data
# mandatfordeling
# geografi
# valgdeltagelse
# valgresultater

# %%
# print the content of the file path + partistemmefordeling-Folketingsvalg-København-Østerbro-260220261723.json
file_path = "partistemmefordeling-Folketingsvalg-København-Østerbro-260220261723.json"
with sftp.open(file_path, "r") as f:
    content = f.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # print the content of the file path + partistemmefordeling-Folketingsvalg-København-Østerbro-260220261723.json
#       2 file_path = "partistemmefordeling-Folketingsvalg-København-Østerbro-260220261723.json"
# ----> 3 with sftp.open(file_path, "r") as f:
#       4     content = f.read()
#       5     print(content)
#
# File ~/Library/CloudStorage/OneDrive-AlrowMedia/Dokumenter/GitHub/FV26/.venv-1/lib/python3.13/site-packages/paramiko/sftp_client.py:372, in SFTPClient.open(self, filename, mode, bufsize)
#     370     imode |= SFTP_FLAG_CREATE | SFTP_FLAG_EXCL
#     371 attrblock = SFTPAttributes()
# --> 372 t, msg = self._request(CMD_OPEN, filename, imode, attrblock)
#     373 if t != CMD_HANDLE:
#     374     raise SFTPError("Expected handle")
#
# File ~/Library/CloudStorage/OneDrive-AlrowMedia/Dokumenter/GitHub/FV26/.venv-1/lib/python3.13/site-packages/paramiko/sftp_client.py:857, in SFTPClient._request(self, t, *args)
#     855 def _request(self, t, *args):
#     856     num = self._async_request(type(None), t, *args)
# --> 857     return self._read_response(num)
#
# File ~/Library/CloudStorage/OneDrive-AlrowMedia/Dokumenter/GitHub/FV26/.venv-1/lib/python3.13/site-packages/paramiko/sftp_client.py:909, in SFTPClient._read_response(self, waitfor)
#     906 if num == waitfor:
#     907     # synchronous
#     908     if t == CMD_STATUS:
# --> 909         self._convert_status(msg)
#     910     return t, msg
#     912 # can not rewrite this to deal with E721, either as a None check
#     913 # nor as not an instance of None or NoneType
#
# File ~/Library/CloudStorage/OneDrive-AlrowMedia/Dokumenter/GitHub/FV26/.venv-1/lib/python3.13/site-packages/paramiko/sftp_client.py:938, in SFTPClient._convert_status(self, msg)
#     935     raise EOFError(text)
#     936 elif code == SFTP_NO_SUCH_FILE:
#     937     # clever idea from john a. meinel: map the error codes to errno
# --> 938     raise IOError(errno.ENOENT, text)
#     939 elif code == SFTP_PERMISSION_DENIED:
#     940     raise IOError(errno.EACCES, text)
#
# FileNotFoundError: [Errno 2] No such file
